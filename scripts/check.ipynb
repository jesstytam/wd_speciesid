# %%
# import cv2
# import json
# import os

# # Load your COCO annotations JSON file
# coco_annotations_file = '/home/jess2/wd_speciesid/data/intermediate/coco.json'

# # Load your COCO images directory (path to image files)
# coco_images_directory = '/home/jess2/data/wild_deserts/Beyond the Fence- Tagged'

# # Load your COCO categories (optional, for label mapping)
# coco_categories = {}  # Fill this dictionary with category_id to category_name mappings

# # Load COCO annotations from the JSON file
# with open(coco_annotations_file, 'r') as file:
#     coco_data = json.load(file)

# # Load COCO images
# coco_images = coco_data['images']

# # Load COCO annotations
# coco_annotations = coco_data['annotations']

# # Loop through the images and their corresponding annotations
# for image_info in coco_images[10:]:
#     image_id = image_info['id']
#     image_filename = image_info['file_name']
#     image_path = os.path.join(coco_images_directory, image_filename)
    
#     # Load the image using OpenCV
#     image = cv2.imread(image_path)
    
#     # Get annotations for this image
#     image_annotations = [ann for ann in coco_annotations if ann['image_id'] == image_id]
    
#     # Draw bounding boxes on the image for each annotation
#     for annotation in image_annotations:
#         category_id = annotation['category_id']
#         category_name = coco_categories.get(category_id, f'Category_{category_id}')
        
#         bbox = annotation['bbox']
#         x, y, w, h = [int(val) for val in bbox]
        
#         # Draw the bounding box
#         color = (0, 255, 0)  # Green color
#         thickness = 2
#         cv2.rectangle(image, (x, y), (x + w, y + h), color, thickness)
        
#         # Display the category label
#         font = cv2.FONT_HERSHEY_SIMPLEX
#         font_scale = 0.5
#         font_color = (0, 0, 255)  # Red color
#         cv2.putText(image, category_name, (x, y - 10), font, font_scale, font_color, thickness)
    
#     # Show or save the image with annotations
#     cv2.imshow('COCO Annotations', image)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()

# # Close OpenCV windows (if any are still open)
# cv2.destroyAllWindows()

# %%
import json

md = json.load(open('/home/jess2/wd_speciesid/data/intermediate/md_output.json', 'r'))
md
# Out:
# {'images': [{'file': 'PCAM01/2021-05-24 17-58-33 M 1_3.JPG',
#    'detections': [{'category': '1',
#      'conf': 0.938,
#      'bbox': [0.3115, 0.4263, 0.1704, 0.1763]},
#     {'category': '1',
#      'conf': 0.953,
#      'bbox': [0.854, 0.3916, 0.06933, 0.1562]}]},
#   {'file': 'PCAM01/2021-05-24 18-02-50 M 2_3.JPG',
#    'detections': [{'category': '1',
#      'conf': 0.95,
#      'bbox': [0.7836, 0.3979, 0.1181, 0.2381]},
#     {'category': '1', 'conf': 0.96, 'bbox': [0, 0.5541, 0.2514, 0.2493]},
#     {'category': '1',
#      'conf': 0.969,
#      'bbox': [0.6064, 0.4208, 0.1367, 0.2222]}]},
#   {'file': 'PCAM01/2021-05-24 18-08-37 M 1_3.JPG',
#    'detections': [{'category': '1',
#      'conf': 0.903,
#      'bbox': [0.0332, 0.452, 0.06542, 0.1868]},
#     {'category': '1',
#      'conf': 0.969,
#      'bbox': [0.5395, 0.4562, 0.2045, 0.127]}]},
#   {'file': 'PCAM01/2021-05-24 21-26-03 M 3_3.JPG',
#    'detections': [{'category': '1',
#      'conf': 0.886,
# ...

# %%
old_coco = json.load(open('/home/jess2/wd_speciesid/data/intermediate/md_coco.json', 'r'))
old_coco
# Out:
# {'images': [{'id': 'PCAM01_2021-05-24_17-58-33_M_1_3',
#    'file_name': 'PCAM01/2021-05-24 17-58-33 M 1_3.JPG',
#    'width': 2048,
#    'height': 1440},
#   {'id': 'PCAM01_2021-05-24_18-02-50_M_2_3',
#    'file_name': 'PCAM01/2021-05-24 18-02-50 M 2_3.JPG',
#    'width': 2048,
#    'height': 1440},
#   {'id': 'PCAM01_2021-05-24_18-08-37_M_1_3',
#    'file_name': 'PCAM01/2021-05-24 18-08-37 M 1_3.JPG',
#    'width': 2048,
#    'height': 1440},
#   {'id': 'PCAM01_2021-05-24_21-26-03_M_3_3',
#    'file_name': 'PCAM01/2021-05-24 21-26-03 M 3_3.JPG',
#    'width': 2048,
#    'height': 1440},
#   {'id': 'PCAM01_2021-05-24_21-27-09_M_1_3',
#    'file_name': 'PCAM01/2021-05-24 21-27-09 M 1_3.JPG',
#    'width': 2048,
#    'height': 1440},
#   {'id': 'PCAM01_2021-05-24_22-38-03_M_1_3',
#    'file_name': 'PCAM01/2021-05-24 22-38-03 M 1_3.JPG',
#    'width': 2048,
#    'height': 1440},
#   {'id': 'PCAM01_2021-05-25_01-38-35_M_1_3',
#    'file_name': 'PCAM01/2021-05-25 01-38-35 M 1_3.JPG',
# ...

# %%
coco = json.load(open('/home/jess2/wd_speciesid/data/intermediate/coco.json', 'r'))
coco
# Out:
# {'images': [{'id': 'PCAM01_2021-05-24_17-58-33_M_1_3',
#    'file_name': 'PCAM01/2021-05-24 17-58-33 M 1_3.JPG',
#    'width': 2048,
#    'height': 1440},
#   {'id': 'PCAM01_2021-05-24_18-02-50_M_2_3',
#    'file_name': 'PCAM01/2021-05-24 18-02-50 M 2_3.JPG',
#    'width': 2048,
#    'height': 1440},
#   {'id': 'PCAM01_2021-05-24_18-08-37_M_1_3',
#    'file_name': 'PCAM01/2021-05-24 18-08-37 M 1_3.JPG',
#    'width': 2048,
#    'height': 1440},
#   {'id': 'PCAM01_2021-05-24_21-26-03_M_3_3',
#    'file_name': 'PCAM01/2021-05-24 21-26-03 M 3_3.JPG',
#    'width': 2048,
#    'height': 1440},
#   {'id': 'PCAM01_2021-05-24_21-27-09_M_1_3',
#    'file_name': 'PCAM01/2021-05-24 21-27-09 M 1_3.JPG',
#    'width': 2048,
#    'height': 1440},
#   {'id': 'PCAM01_2021-05-24_22-38-03_M_1_3',
#    'file_name': 'PCAM01/2021-05-24 22-38-03 M 1_3.JPG',
#    'width': 2048,
#    'height': 1440},
#   {'id': 'PCAM01_2021-05-25_01-38-35_M_1_3',
#    'file_name': 'PCAM01/2021-05-25 01-38-35 M 1_3.JPG',
# ...
